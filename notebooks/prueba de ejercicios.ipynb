# %%
import sys

sys.path.append("../src")
print(sys.path)
# Out:
# ['C:\\Users\\PC Store\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\PC Store\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\PC Store\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\PC Store\\AppData\\Local\\Programs\\Python\\Python313', 'c:\\Users\\PC Store\\Practica2\\.venv', '', 'c:\\Users\\PC Store\\Practica2\\.venv\\Lib\\site-packages', '../src']

# %%
# 1.Estadistica de un texto
import estadistica_1
estadistica_1.Estadistica_Texto()
# Out:
# Total de lineas : 19
# Total de palabras : 137
# promedio de palabras por linea :7.2105263157894735
# - Special cases aren't special enough to break the rules.(9 palabras)
# - In the face of ambiguity, refuse the temptation to guess.(10 palabras)
# - There should be one-- and preferably only one --obvious way to do it.(13 palabras)
# - Although that way may not be obvious at first unless you're Dutch.(12 palabras)
# - Although never is often better than *right* now.(8 palabras)
# - If the implementation is hard to explain, it's a bad idea.(11 palabras)
# - If the implementation is easy to explain, it may be a good idea.(13 palabras)
# - Namespaces are one honking great idea -- let's do more of those!(12 palabras)

# %%
# 2.Duracion de una playlist
import playlist_2
playlist_2.DuracionDeUnaPlaylist()
# Out:
# 46.88333333333333
#  la cancion mas larga es :Stairway to Heaven
#  la cancion mas corta es :Imagine

# %%
# 3.Filtro de spoilers 
import spoilers_3
palabras = input("ingrese las palabras spoiler(separadas por coma) :")
spoilers_3.FiltrodeSpoilers(palabras)
# Out:
# La película sigue a un grupo de astronautas que viajan a Marte en una misión de rescate. El capitán Torres lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. Al llegar a Marte descubren que la base está abandonada y los suministros destruidos. Torres decide sacrificar la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia. El final revela que Torres sobrevivió gracias a un pasaje secreto.

# %%
# 4.Validacion de email
import email_4
email = input(" ingrese un email  : ")

email_4.ValidacionDeEmail(email)
# Out:
# El email ingresado: 23
# El email no es valido.

# %%
# 5.Calculadora de  costo de envio
import calculadora_5
peso = float(input("ingrese el peso del paquete (kg) :"))
zona = input("ingrese la zona de destino(loscal/regional/nacional) :")

calculadora_5.CalculadoraDeEnvios(peso,zona)
# Out:
# 4500

# %%
# 6.Analisis de hashtags
import hashtags_6
hashtags_6.AnalisisDeHashtags()
# Out:
# hashtags trending (mas de una aparicion) :
# #Motivación 2
# #Python 3
# #Programación 3
# #SerieAdicta 2
# #InteligenciaArtificial 3
# #Tecnología 2
#
# total hashtags unicos: 13

# %%
# 7.Sorteo de amigo invisible
import sorteo_7
nombres = input("ingrese los participantes(separados por coma): ").lower().strip()
sorteo_7.SorteoDeAmigos(nombres)

#no terminado

# %%
# 8. Cifrado cesar
import cifrado_8
mensaje = input("ingrese un mensaje :")
desplazamiento = int(input("ingrese un valor de desplazamientoo(numero entero) :"))

cifrado_8.CifradoCesar(mensaje,desplazamiento)

# %%
# 9.Normalizacion de registros  de alumnos
import alumnos_9
alumnos_9.NormalizacionDeAlumnos()
# Out:
# Registro limpios de alumnos :
# --------------------------------------------------
# Nombre                     Nota    Estado
# Ana García                  9        Aprobado
# Carlos Ruiz                 6        Aprobado
# Gabriela Ríos               5        Aprobado
# Laura Méndez                8        Aprobado
# María Fernández             10       Aprobado
# Pedro López                 4        Desaprobado
# Sofía Torres                9        Aprobado

# %%
# 10.simulacion de competencia de cocina y  ranking
import competencia_10
competencia_10.CompetenciaDeCocineros()
# Out:
# Ronda 1  - Entrada
#
# El ganador es :Camila(26pts)
# Cocinero        Puntaje     Rondas ganadas     Mejor puntaje     Promedio
# ------------------------------------------------------------
# Camila            26             1                 26               5.2
# Valentina         24             0                 24               4.8
# Lucía             24             0                 24               4.8
# Mateo             22             0                 22               4.4
# Santiago          19             0                 19               3.8
# ------------------------------------------------------------
#
# Ronda 2  - Plato principal
#
# El ganador es :Valentina(26pts)
# Cocinero        Puntaje     Rondas ganadas     Mejor puntaje     Promedio
# ------------------------------------------------------------
# Valentina         50             1                 26               10.0
# Mateo             46             0                 24               9.2
# ...
